# %%
import os
from google.colab import drive

drive.mount('/content/drive')

path = "/content/drive/My Drive"

os.chdir(path)
os.listdir(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['TransE-master', 'Colab Notebooks']

# %%
cd '/content/drive/MyDrive/TransE-master/FB15k'
# Out:
# /content/drive/MyDrive/TransE-master/FB15k

# %%
# !python '/content/drive/MyDrive/TransE-master/src/transE_simple.py'
# Out:
# load file...
# Complete load. entity : 14951 , relation : 1345 , triple : 483142
# batch size:  1207
# epoch:  0 cost time: 76.311
# loss:  0.986944820045318
# epoch:  1 cost time: 71.523
# loss:  0.42760033847355833
# epoch:  2 cost time: 67.45
# loss:  0.3405790766236762
# epoch:  3 cost time: 66.263
# loss:  0.22695196794146477
# epoch:  4 cost time: 66.28
# loss:  0.2550771402283506
# epoch:  5 cost time: 66.432
# loss:  0.211956264570683
# epoch:  6 cost time: 66.4
# loss:  0.22008914677414718
# epoch:  7 cost time: 66.27
# loss:  0.14863863492975782
# epoch:  8 cost time: 66.416
# loss:  0.18325705922194468
# epoch:  9 cost time: 65.952
# loss:  0.12616467371363171
# epoch:  10 cost time: 65.303
# loss:  0.182263760627216
# epoch:  11 cost time: 66.151
# loss:  0.14215366979789246
# epoch:  12 cost time: 66.505
# loss:  0.13693843061176103
# epoch:  13 cost time: 66.986
# loss:  0.17657584925286815
# epoch:  14 cost time: 66.822
# loss:  0.15092933515087148
# ...
